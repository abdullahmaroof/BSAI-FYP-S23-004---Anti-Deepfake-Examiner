# %%
from tkinter import *
from PIL import ImageTk, Image
from ipynb.fs.full.Voice_setup import *


def about(root):
    root.destroy()
    class aboutgui:
        def __init__(self, root):
            self.root = root
            root.geometry("1400x700")
            root.maxsize(1400,700)
            root.minsize(1400,700)
            
            root.title("Anti Deepfake Examiner/About Coder Tech")
            
            Header_frame = Frame(root, bg="medium spring green", height=150)
        
            Header_block1 = Frame(Header_frame, bg="medium spring green", height=68)
            title_label = Label(Header_block1, text="Anti Deepfake Examiner", bg="medium spring green",
                            font=('Garuda', 30, 'bold', 'italic'))
            tagline_label = Label(Header_block1, text="(\"Guarding Truth: Unmasking Deception with Deepfake Vigilance\")",
                             bg="medium spring green", fg="navy",
                            font=('Garuda', 15, 'bold', 'italic'))
        
        
            Center_frame = Frame(root, bg="black", height=550)
            
            centerfame_top = Frame(Center_frame, bg="orchid", height=100)
            Aboutheading_label = Label(centerfame_top, text="CODER TECH TEAM", font=('Garuda', 20, 'italic', 'bold'), 
                                       bg="DodgerBlue3", width=30, height=2, fg='white')
            
            centerfame_bottom = Frame(Center_frame, bg="orchid", height=450)
            
            Centerblock1 = Frame(centerfame_bottom, width=400, height=450, bg="orchid")
            
            centerblock1_Imageframe = Frame(Centerblock1, height=350, bg="orchid")
            self.team1_pic = Image.open("abdullah.png")
            self.resizedt1 = self.team1_pic.resize((350, 350), Image.Resampling.LANCZOS)
            self.t1pic = ImageTk.PhotoImage(self.resizedt1)
            pic1_label = Label(centerblock1_Imageframe, bg="orchid", width=350, height=350, image=self.t1pic)
            
            centerblock1_Buttonframe = Frame(Centerblock1, height=100, bg="orchid")
            t1_button = Button(centerblock1_Buttonframe, text="Abdullah Maroof", bg="DodgerBlue3", 
                               font=('Garuda',12,'bold'), width=20, height=1, fg="mint cream", 
                               activebackground="mint cream", activeforeground="DodgerBlue3",
                              command= lambda : voice_aboutabdullah.wishme())
            
            
            Centerblock2 = Frame(centerfame_bottom, width=400, height=450, bg="orchid")
            centerblock2_Imageframe = Frame(Centerblock2, height=300, bg="orchid")
            self.team2_pic = Image.open("abubakkar.png")
            self.resizedt2 = self.team2_pic.resize((350, 350), Image.Resampling.LANCZOS)
            self.t2pic = ImageTk.PhotoImage(self.resizedt2)
            pic2_label = Label(centerblock2_Imageframe, bg="orchid", width=350, height=350, image=self.t2pic)
            
            
            centerblock2_Buttonframe = Frame(Centerblock2, height=150, bg="orchid")
            t2_button = Button(centerblock2_Buttonframe, text="AbuBakkar Siddque", bg="DodgerBlue3", 
                               font=('Garuda',12,'bold'), width=20, height=1, fg="mint cream", 
                               activebackground="mint cream", activeforeground="DodgerBlue3",
                              command= lambda : voice_aboutabubakkar.wishme())
            
            
            
            Centerblock3 = Frame(centerfame_bottom, width=400, height=450, bg="orchid")
            centerblock3_Imageframe = Frame(Centerblock3, height=300, bg="orchid")
            self.team3_pic = Image.open("zubair.png")
            self.resizedt3 = self.team3_pic.resize((350, 350), Image.Resampling.LANCZOS)
            self.t3pic = ImageTk.PhotoImage(self.resizedt3)
            pic3_label = Label(centerblock3_Imageframe, bg="orchid", width=350, height=350, image=self.t3pic)
            
            centerblock3_Buttonframe = Frame(Centerblock3, height=150, bg="orchid")
            t3_button = Button(centerblock3_Buttonframe, text="M Zubair Ali", bg="DodgerBlue3", 
                               font=('Garuda',12,'bold'), width=20, height=1, fg="mint cream", 
                               activebackground="mint cream", activeforeground="DodgerBlue3",
                              command= lambda : voice_aboutzubair.wishme())
            
            Footer_frame = Frame(root, bg="medium spring green", height=50)
            copytight_label = Label(Footer_frame, text="© CODER TECH 2023, All Rights Reserved", bg="medium spring green",
                                font=('Garuda',12,'bold'))
        
        
            Header_frame.pack(side=TOP, fill=BOTH)
            Header_block1.pack(side=TOP, fill=BOTH, pady=15)
            title_label.pack(pady=(0,3))
            tagline_label.pack()
        
        
            Center_frame.pack(side=TOP, fill=BOTH)
            
            centerfame_top.pack(side=TOP, fill=BOTH, expand=1)
            Aboutheading_label.pack(pady=10)
            
            centerfame_bottom.pack(side=TOP, fill=BOTH, expand=1, pady=(2,0))
            
            Centerblock1.pack(side=LEFT, fill=BOTH, expand=1)
            centerblock1_Imageframe.pack(side=TOP, fill=BOTH)
            pic1_label.pack(side=TOP, fill=BOTH, padx=25, pady=5)
            
            centerblock1_Buttonframe.pack(side=TOP, fill=BOTH, pady=(0,20))
            t1_button.pack(pady=20)
            
            
            Centerblock2.pack(side=LEFT, fill=BOTH, expand=1)
            centerblock2_Imageframe.pack(side=TOP, fill=BOTH)
            pic2_label.pack(side=TOP, fill=BOTH, padx=25, pady=5)
            
            centerblock2_Buttonframe.pack(side=TOP, fill=BOTH, pady=(0,20))
            t2_button.pack(pady=20)
            
            Centerblock3.pack(side=LEFT, fill=BOTH, expand=1)
            centerblock3_Imageframe.pack(side=TOP, fill=BOTH)
            pic3_label.pack(side=TOP, fill=BOTH, padx=25, pady=5)
            
            centerblock3_Buttonframe.pack(side=TOP, fill=BOTH, pady=(0,20))
            t3_button.pack(pady=20)
            
            
            Footer_frame.pack(side=BOTTOM, fill=BOTH)
            copytight_label.pack(pady=5)
            
            voice_aboutus.wishme()
            
    root = Tk()
    obj = aboutgui(root)
    mainloop()
